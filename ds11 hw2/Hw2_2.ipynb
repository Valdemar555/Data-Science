# %%
import pandas as pd

# %% [markdown]
# **Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv**

# %%
file_id = '1JMYqXipZpz9Y5-vyxvLEO2Y1sRBxqu-U'
url = f'https://drive.google.com/uc?id={file_id}'
data = pd.read_csv(url)
#print(data)

# %% [markdown]
# **Прочитайте отриману таблицю, використовуючи метод head**

# %%
data.head()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# ...

# %% [markdown]
# **Визначте розмір таблиці за допомогою методу shape**

# %%
data.shape
# Out:
# (8704, 25)

# %% [markdown]
# **Визначте типи всіх стовпців за допомогою dataframe.dtypes**

# %%
data.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# ...

# %% [markdown]
# **Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)**

# %%
data.isnull().sum()
data.columns
for i in data.columns:
    print(f"В колонці {i} частка пропусків складає {data[i].isnull().sum()/len(data[i])}")
# Out:
# В колонці N частка пропусків складає 0.0
# В колонці Должность частка пропусків складає 0.0
# В колонці Язык.программирования частка пропусків складає 0.4423253676470588
# В колонці Специализация частка пропусків складає 0.8293887867647058
# В колонці Общий.опыт.работы частка пропусків складає 0.0
# В колонці Опыт.работы.на.текущем.месте частка пропусків складає 0.0
# В колонці Зарплата.в.месяц частка пропусків складає 0.0
# В колонці Изменение.зарплаты.за.12.месяцев частка пропусків складає 0.0
# В колонці Город частка пропусків складає 0.0
# В колонці Размер.компании частка пропусків складає 0.0
# В колонці Тип.компании частка пропусків складає 0.0
# В колонці Пол частка пропусків складає 0.0
# В колонці Возраст частка пропусків складає 0.0
# В колонці Образование частка пропусків складає 0.0
# В колонці Университет частка пропусків складає 0.04113051470588235
# В колонці Еще.студент частка пропусків складає 0.0
# В колонці Уровень.английского частка пропусків складає 0.0
# ...

# %% [markdown]
# **Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування", Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"**

# %%
new_data=data.copy()
drop_data = new_data.isna().any()
cols_ignore = ['Язык.программирования']
drop_data[cols_ignore] = False
new_data.drop(drop_data.index[drop_data], axis=1, inplace=True)
new_data.isnull().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Еще.студент                            0
# Уровень.английского                    0
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# dtype: int64

# %% [markdown]
# **Видаліть усі рядки у вихідній таблиці за допомогою методу dropna; Визначте новий розмір таблиці за допомогою методу shape**

# %%
zero_data=new_data.dropna(inplace=True)
zero_data.shape

# %% [markdown]
# **Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python; Визначте розмір таблиці python_data за допомогою методу shape**

# %%
python_data = pd.DataFrame(data.loc[data['Язык.программирования'] == 'Python'])
python_data
# Out:
#          N                 Должность Язык.программирования Специализация  \
# 12      13         Software Engineer                Python           NaN
# 68      69         Software Engineer                Python           NaN
# 87      88  Junior Software Engineer                Python           NaN
# 114    115  Junior Software Engineer                Python           NaN
# 143    144  Junior Software Engineer                Python           NaN
# ...    ...                       ...                   ...           ...
# 8546  8547         Software Engineer                Python           NaN
# 8625  8626         Software Engineer                Python           NaN
# 8635  8636  Senior Software Engineer                Python           NaN
# 8673  8674  Junior Software Engineer                Python           NaN
# 8695  8696         Software Engineer                Python           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# ...

# %%
python_data.shape
# Out:
# (207, 25)

# %% [markdown]
# **Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"**

# %%
position = python_data.groupby(['Должность'])

# %%
position.head()
# Out:
#          N                 Должность Язык.программирования Специализация  \
# 12      13         Software Engineer                Python           NaN
# 68      69         Software Engineer                Python           NaN
# 87      88  Junior Software Engineer                Python           NaN
# 114    115  Junior Software Engineer                Python           NaN
# 143    144  Junior Software Engineer                Python           NaN
# 153    154         Software Engineer                Python           NaN
# 162    163  Junior Software Engineer                Python           NaN
# 171    172  Junior Software Engineer                Python           NaN
# 217    218         Software Engineer                Python           NaN
# 302    303  Senior Software Engineer                Python           NaN
# 373    374  Senior Software Engineer                Python           NaN
# 387    388         Software Engineer                Python           NaN
# ...

# %% [markdown]
# **Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"**

# %%
range_salary = position.agg({'Зарплата.в.месяц':['min', 'max']})
range_salary
# Out:
#                          Зарплата.в.месяц
#                                       min   max
# Должность
# Junior Software Engineer              100  1250
# Senior Software Engineer             1300  9200
# Software Engineer                     500  5400
# System Architect                     3000  5000
# Technical Lead                       1425  6200

# %% [markdown]
# **Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"**

# %%
def fill_avg_salary(x):
    return x.mean()

# %%
range_salary['mean'] = range_salary.apply(fill_avg_salary, axis=1)
range_salary
# Out:
#                          Зарплата.в.месяц          mean
#                                       min   max
# Должность
# Junior Software Engineer              100  1250   675.0
# Senior Software Engineer             1300  9200  5250.0
# Software Engineer                     500  5400  2950.0
# System Architect                     3000  5000  4000.0
# Technical Lead                       1425  6200  3812.5

# %% [markdown]
# **Створіть описову статистику за допомогою методу describe для нового стовпчи**

# %%
range_salary['mean'].describe()
# Out:
# count       5.000000
# mean     3337.500000
# std      1700.091909
# min       675.000000
# 25%      2950.000000
# 50%      3812.500000
# 75%      4000.000000
# max      5250.000000
# Name: mean, dtype: float64

# %% [markdown]
# **Збережіть отриману таблицю в CSV файл**

# %%
range_salary.to_csv('Range_Salary.csv')
