# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Прочитайте csv файл (використовуйте функцію read_csv)**

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/bestsellers.csv')
data
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ****Виведіть перші п'ять рядків (використовується функція head) **Текст, выделенный полужирным шрифтом**

# %%
data.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# **Виведіть розміри датасету (використовуйте атрибут shape)**

# %%
data.shape
# Out:
# (550, 7)

# %% [markdown]
# Про скільки книг зберігає дані датасет?-**550**

# %%
data.columns = ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']

# %%
data.head(5)
# Out:
#                                                 name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      author  user_rating  reviews  price  year        genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# Перевірте, чи у всіх рядків вистачає даних: виведіть кількість пропусків (na) у кожному зі стовпців (використовуйте функції isna та sum).Чи є в якихось змінних пропуски?- **Ні**

# %%
for i in data.columns:
    print(f"В стовбчику {i} кількість пропусків складає {data[i].isnull().sum()}")
# Out:
# В стовбчику name кількість пропусків складає 0
# В стовбчику author кількість пропусків складає 0
# В стовбчику user_rating кількість пропусків складає 0
# В стовбчику reviews кількість пропусків складає 0
# В стовбчику price кількість пропусків складає 0
# В стовбчику year кількість пропусків складає 0
# В стовбчику genre кількість пропусків складає 0

# %% [markdown]
# Перевірте, які є унікальні значення в колонці genre (використовуйте функцію unique).Які є унікальні жанри? -**Non Fiction', 'Fiction**

# %%
data['genre'].unique()
# Out:
# array(['Non Fiction', 'Fiction'], dtype=object)

# %% [markdown]
# Тепер подивіться на розподіл цін: побудуйте діаграму (використовуйте kind='hist').

# %%
data[['price']].plot(kind='hist', fontsize=10, grid=True)
plt.show()

# %%
data['price'].describe()
# Out:
# count    550.000000
# mean      13.100000
# std       10.842262
# min        0.000000
# 25%        7.000000
# 50%       11.000000
# 75%       16.000000
# max      105.000000
# Name: price, dtype: float64

# %% [markdown]
# Mаксимальна ціна: 105
#
# Мінімальна ціна: 0
#
# Середня ціна: 13.1
#
# Медіанная ціна: 11

# %% [markdown]
# **Пошук та сортування даних**

# %%
data['user_rating'].max()
#Який рейтинг у датасеті найвищий? Відповідь: 4.9
# Out:
# 4.9

# %%
len(data.where(data['user_rating'] == data['user_rating'].max()).dropna())
# Скільки книг мають такий рейтинг? Відповідь:52
# Out:
# 52

# %%
data.where(data['reviews'] == data['reviews'].max()).dropna()
# Яка книга має найбільше відгуків? Відповідь:Where the Crawdads Sing	Delia Owens
# Out:
#                         name       author  user_rating  reviews  price  \
# 534  Where the Crawdads Sing  Delia Owens          4.8  87841.0   15.0
#
#        year    genre
# 534  2019.0  Fiction

# %%
books_2015 = data.where(data['year'] == 2015).dropna()

# %%
books_2015.where(books_2015['price'] == books_2015['price'].max()).dropna()
#З тих книг, що потрапили до Топ-50 у 2015 році, яка книга найдорожча (можна використати проміжний датафрейм)? Відповідь: Publication Manual of the American Psychologic..
# Out:
#                                                   name  \
# 277  Publication Manual of the American Psychologic...
#
#                                  author  user_rating  reviews  price    year  \
# 277  American Psychological Association          4.5   8580.0   46.0  2015.0
#
#            genre
# 277  Non Fiction

# %%
len(data.where((data['genre'] == 'Fiction') & (data['year'] == 2010)).dropna())
#Скільки книг жанру Fiction потрапили до Топ-50 у 2010 році (використовуйте &)? Відповідь: 20
# Out:
# 20

# %%
books_2010_2011 = data[(data["user_rating"] == 4.9) & (data["year"].isin([2010, 2011]))]
len(books_2010_2011)
#Скільки книг з рейтингом 4.9 потрапило до рейтингу у 2010 та 2011 роках (використовуйте | або функцію isin)? Відповідь: 1
# Out:
# 1

# %%
data[(data["price"] < 8) & (data["year"] == 2015)].sort_values("price")
#Давайте відсортуємо за зростанням ціни всі книги, які потрапили до рейтингу в 2015 році і коштують дешевше за 8 доларів (використовуйте функцію sort_values). Яка книга остання у відсортованому списку? Відповідь:Old School (Diary of a Wimpy Kid #10)
# Out:
#                                                   name              author  \
# 507                              To Kill a Mockingbird          Harper Lee
# 210                      Laugh-Out-Loud Jokes for Kids         Rob Elliott
# 206                         Knock-Knock Jokes for Kids         Rob Elliott
# 111                                    First 100 Words        Roger Priddy
# 123                               Giraffes Can't Dance       Giles Andreae
# 54   Creative Haven Creative Cats Coloring Book (Ad...     Marjorie Sarnat
# 63                      Dear Zoo: A Lift-the-Flap Book        Rod Campbell
# 89   Dover Creative Haven Art Nouveau Animal Design...         Marty Noble
# 478                        The Very Hungry Caterpillar          Eric Carle
# 201  Killing Reagan: The Violent Assault That Chang...       Bill O'Reilly
# 28                        Baby Touch and Feel: Animals                  DK
# ...

# %% [markdown]
# **Агрегування даних та з'єднання таблиць**

# %%
data.groupby(['genre']).agg({'price':['min', 'max']})
#Максимальна ціна для жанру Fiction: Відповідь 82
#Мінімальна ціна для жанру Fiction: Відповідь 0
#Максимальна ціна для жанру Non Fiction: Відповідь 105
#Мінімальна ціна для жанру Non Fiction: Відповідь 0
# Out:
#             price
#               min  max
# genre
# Fiction         0   82
# Non Fiction     0  105

# %% [markdown]
# Тепер створіть новий датафрейм, який вміщатиме кількість книг для кожного з авторів (використовуйте функції groupby та agg, для підрахунку кількості використовуйте count).

# %%
author = data.groupby(['author']).agg({'author':'count'}).rename(columns = {'author':  'number'})
author
# Out:
#                             number
# author
# Abraham Verghese                 2
# Adam Gasiewski                   1
# Adam Mansbach                    1
# Adir Levy                        1
# Admiral William H. McRaven       1
# ...                            ...
# Walter Isaacson                  3
# William Davis                    2
# William P. Young                 2
# Wizards RPG Team                 3
# Zhi Gang Sha                     2
#
# [248 rows x 1 columns]

# %% [markdown]
# Якої розмірності вийшла таблиця? Відповідь: 248

# %%
author.shape
# Out:
# (248, 1)

# %%
author.loc[author['number'] == author['number'].max()]
#Який автор має найбільше книг? Відповідь: Jeff Kinney
#Скільки книг цього автора? Відповідь: 12
# Out:
#              number
# author
# Jeff Kinney      12

# %% [markdown]
# Тепер створіть другий датафрейм, який буде вміщати середній рейтинг для кожного автора (використовуйте функції groupby та agg, для підрахунку середнього значення використовуйте mean).

# %%
avg = data.groupby(['author']).agg({'user_rating':'mean'}).rename(columns = {'user_rating':  'avg_rating'})

# %%
avg.loc[avg['avg_rating'] == avg['avg_rating'].min()]
#У якого автора середній рейтинг мінімальний? Відповідь:Donna Tartt
#Який у цього автора середній рейтинг? Відповідь: 3.9
# Out:
#              avg_rating
# author
# Donna Tartt         3.9

# %% [markdown]
# З'єднайте останні два датафрейми так, щоб для кожного автора було видно кількість книг та середній рейтинг (Використовуйте функцію concat з параметром axis=1). Збережіть результат у змінну

# %%
join_author = pd.concat([author, avg], axis=1).reset_index()
join_author
# Out:
#                          author  number  avg_rating
# 0              Abraham Verghese       2    4.600000
# 1                Adam Gasiewski       1    4.400000
# 2                 Adam Mansbach       1    4.800000
# 3                     Adir Levy       1    4.800000
# 4    Admiral William H. McRaven       1    4.700000
# ..                          ...     ...         ...
# 243             Walter Isaacson       3    4.566667
# 244               William Davis       2    4.400000
# 245            William P. Young       2    4.600000
# 246            Wizards RPG Team       3    4.800000
# 247                Zhi Gang Sha       2    4.600000
#
# [248 rows x 3 columns]

# %%
join_author.sort_values(by=['number', 'avg_rating'])
#Який автор перший у списку?Відповідь - Muriel Barbery
# Out:
#                                  author  number  avg_rating
# 171                      Muriel Barbery       1    4.000000
# 43                         Chris Cleave       1    4.100000
# 109                   Ian K. Smith M.D.       1    4.100000
# 186                        Pierre Dukan       1    4.100000
# 81                     Elizabeth Strout       1    4.200000
# ..                                  ...     ...         ...
# 11   American Psychological Association      10    4.500000
# 226                     Suzanne Collins      11    4.663636
# 92                         Gary Chapman      11    4.736364
# 197                        Rick Riordan      11    4.772727
# 120                         Jeff Kinney      12    4.800000
#
# [248 rows x 3 columns]
