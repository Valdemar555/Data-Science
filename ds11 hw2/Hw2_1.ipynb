# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# **Прочитайте дані за допомогою методу read_html з таблиці "Коефіцієнт народжуваності в регіонах України (1950—2019)"**

# %%
url = 'https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8'
zaput = requests.get(url)
page = zaput.text
table = pd.read_html(page, match='Коефіцієнт народжуваності в регіонах України', encoding="UTF-8", thousands='.',decimal=',')
print(table[0])
# Out:
#                Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0                Крим  23.0  20.6  16.0  13.0   7.3  12.6     —     —
# 1           Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2           Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3    Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4            Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2     —
# 5         Житомирська  26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# 6        Закарпатська  31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# 7          Запорізька  21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# 8   Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# 9            Київська  20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# 10     Кіровоградська  21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# 11          Луганська  26.2  23.5  14.4  11.6   6.2   9.6   5.1     —
# ...

# %% [markdown]
# **Вивести перші рядки таблиці за допомогою методу head**

# %%
df_natality = pd.DataFrame(table[0])
df_natality.head()
# Out:
#              Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0              Крим  23.0  20.6  16.0  13.0   7.3  12.6     —     —
# 1         Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2         Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3  Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4          Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2     —

# %% [markdown]
# **Визначте кількість рядків та стовпців у датафреймі (атрибут shape)**

# %%
df_natality.shape
# Out:
# (28, 9)

# %% [markdown]
# **Замініть у таблиці значення "—" на значення NaN**

# %%
df_natality.replace('—',np.nan, inplace=True)
df_natality
# Out:
#                Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0                Крим  23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# 1           Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2           Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3    Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4            Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN
# 5         Житомирська  26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# 6        Закарпатська  31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# 7          Запорізька  21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# 8   Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# 9            Київська  20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# 10     Кіровоградська  21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# 11          Луганська  26.2  23.5  14.4  11.6   6.2   9.6   5.1   NaN
# ...

# %% [markdown]
# **Визначте типи всіх стовпців за допомогою dataframe.dtypes**

# %%
df_natality.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990      float64
# 2000      float64
# 2012      float64
# 2014       object
# 2019       object
# dtype: object

# %% [markdown]
# **Замініть типи нечислових колонок на числові. Підказка - це колонки, де знаходився символ "—"**

# %%
df_natality = df_natality.apply(pd.to_numeric, errors='ignore')
df_natality.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990      float64
# 2000      float64
# 2012      float64
# 2014      float64
# 2019      float64
# dtype: object

# %% [markdown]
# **Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)**

# %%
df_natality.isnull().sum()
# Out:
# Регіон    0
# 1950      2
# 1960      1
# 1970      1
# 1990      0
# 2000      0
# 2012      0
# 2014      2
# 2019      4
# dtype: int64

# %% [markdown]
# **Видаліть з таблиці дані по всій країні, останній рядок таблиці**

# %%
df_natality.drop(index=df_natality.index[-1],axis=0, inplace=True)
df_natality
# Out:
#                Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0                Крим  23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# 1           Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2           Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3    Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4            Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN
# 5         Житомирська  26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# 6        Закарпатська  31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# 7          Запорізька  21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# 8   Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# 9            Київська  20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# 10     Кіровоградська  21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# 11          Луганська  26.2  23.5  14.4  11.6   6.2   9.6   5.1   NaN
# ...

# %% [markdown]
# **Замініть відсутні дані в стовпцях середніми значеннями цих стовпців (метод fillna)**

# %%
for i in df_natality.keys():
  if i.isdigit():
    df_natality.fillna({i: df_natality[i].mean()}, inplace=True)
df_natality
# Out:
#                Регіон    1950       1960  1970  1990  2000  2012    2014  \
# 0                Крим  23.000  20.600000  16.0  13.0   7.3  12.6  11.144
# 1           Вінницька  22.400  19.200000  14.2  12.4   8.4  11.2  10.900
# 2           Волинська  24.700  25.000000  17.9  15.3  11.2  14.8  14.100
# 3    Дніпропетровська  20.400  20.400000  15.1  12.3   7.1  11.2  11.100
# 4            Донецька  27.100  21.400000  14.0  10.9   6.1   9.8   8.200
# 5         Житомирська  26.100  22.300000  15.9  12.9   8.9  12.2  12.000
# 6        Закарпатська  31.400  27.300000  20.7  16.8  11.5  15.1  14.600
# 7          Запорізька  21.900  19.700000  15.0  12.4   7.1  10.6  10.600
# 8   Івано-Франківська  24.300  24.800000  18.2  15.5  10.3  12.4  12.200
# 9            Київська  20.400  18.900000  15.6  12.3   7.3  12.2  12.100
# 10     Кіровоградська  21.600  17.100000  14.5  12.6   7.9  11.0  10.800
# 11          Луганська  26.200  23.500000  14.4  11.6   6.2   9.6   5.100
# ...

# %% [markdown]
# **Отримайте список регіонів, де рівень народжуваності у 2019 році був вищим за середній по Україні**

# %%
df_natality[['Регіон','2019']].where(df_natality['2019']>df_natality['2019'].mean()+0.1).dropna()
# Out:
#                Регіон  2019
# 2           Волинська  10.1
# 6        Закарпатська  10.4
# 8   Івано-Франківська   8.8
# 12          Львівська   8.7
# 14            Одеська   8.8
# 16         Рівненська  10.7
# 23        Чернівецька   9.2
# 25               Київ  11.0

# %% [markdown]
# **У якому регіоні була найвища народжуваність у 2014 році?**

# %%
df_natality[['Регіон','2014']].where(df_natality['2014']==df_natality['2014'].max()).dropna()
# Out:
#         Регіон  2014
# 16  Рівненська  14.8

# %% [markdown]
# **Побудуйте стовпчикову діаграму народжуваності по регіонах у 2019 році**

# %%
import matplotlib.pyplot as plt
df_natality[['Регіон','2019']].plot(kind='barh', x='Регіон', legend=False, xticks=range(12), grid=True)
plt.show()
